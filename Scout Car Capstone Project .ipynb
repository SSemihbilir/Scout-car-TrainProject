# %% [markdown]
# # Capstone Project
#
# ## Part One: Understanding the Background and Data

# %% [markdown]
# ----
#
#
# ### The Data
#
#
# #### scout_car_train.json

# %% [markdown]
# ## Part Two: Exploring Data
#
# Let's first explore
#
# **TASK: Run the cell below to read in the scout_car_train.json file**

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
import numpy as np

import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import json

# %%
df = pd.read_json("scout_car_train.json",lines=True)

# %% [markdown]
# **TASK: Explore the DataFrame Properties and Head.**

# %%
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# ...                                                  ...             ...
# 15755  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15756  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15757  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15758  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15759  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15760 entries, 0 to 15759
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15760 non-null  object
#  1   make_model                     15760 non-null  object
#  2   short_description              15716 non-null  object
#  3   body_type                      15700 non-null  object
#  4   price                          15760 non-null  int64
#  5   vat                            11291 non-null  object
#  6   km                             15760 non-null  object
#  7   registration                   15760 non-null  object
#  8   prev_owner                     9002 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15760 non-null  object
#  11  Type                           15758 non-null  object
# ...

# %%
df.describe()
# Out:
#               price   kW
# count  15760.000000  0.0
# mean   18016.664213  NaN
# std     7388.164988  NaN
# min       13.000000  NaN
# 25%    12840.000000  NaN
# 50%    16900.000000  NaN
# 75%    21900.000000  NaN
# max    74600.000000  NaN

# %%
df.corr()
# Out:
# C:\Users\ssbil\AppData\Local\Temp\ipykernel_8320\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#        price  kW
# price    1.0 NaN
# kW       NaN NaN

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %% [markdown]
# **TASK: Let's explore the relationship**

# %%
sns.histplot(data=df,x="price",kde=True,bins=25)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
df[["make_model","price"]]
# Out:
#            make_model  price
# 0             Audi A1  15770
# 1             Audi A1  14500
# 2             Audi A1  14640
# 3             Audi A1  14500
# 4             Audi A1  15090
# ...               ...    ...
# 15755  Renault Espace  39950
# 15756  Renault Espace  39885
# 15757  Renault Espace  39875
# 15758  Renault Espace  39700
# 15759  Renault Espace  40999
#
# [15760 rows x 2 columns]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="make_model",y="price",data=df,hue="body_type",style='body_type',s=100)
plt.tight_layout()
plt.legend()

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.countplot(data=df,x="make_model",hue="body_type")
plt.tight_layout()

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df[["Make","Model"]]#bu sütunlar gereksiz silelim
# Out:
#               Make             Model
# 0         \nAudi\n      [\n, A1, \n]
# 1         \nAudi\n      [\n, A1, \n]
# 2         \nAudi\n      [\n, A1, \n]
# 3         \nAudi\n      [\n, A1, \n]
# 4         \nAudi\n      [\n, A1, \n]
# ...            ...               ...
# 15755  \nRenault\n  [\n, Espace, \n]
# 15756  \nRenault\n  [\n, Espace, \n]
# 15757  \nRenault\n  [\n, Espace, \n]
# 15758  \nRenault\n  [\n, Espace, \n]
# 15759  \nRenault\n  [\n, Espace, \n]
#
# [15760 rows x 2 columns]

# %%
df1= df.drop(["Make","Model"],axis=1)

# %% [markdown]
# **Fill the VAT column with "vat included"**

# %%
len(df[df["vat"].isnull()])
# Out:
# 4469

# %%
df["vat"].fillna("VAT included")
# Out:
# 0          VAT deductible
# 1        Price negotiable
# 2          VAT deductible
# 3            VAT included
# 4            VAT included
#                ...
# 15755      VAT deductible
# 15756      VAT deductible
# 15757      VAT deductible
# 15758      VAT deductible
# 15759      VAT deductible
# Name: vat, Length: 15760, dtype: object

# %%
df["km1"]=df["km"].str.split(",")

# %%
df["kmint"] = df["km"].replace(',',"", regex=True).replace("-","0").astype(int)#KM column will change dtype int64

# %% [markdown]
# **Explore the other columns**

# %%
df[["registration","First Registration"]]
# Out:
#       registration First Registration
# 0          01/2016     [\n, 2016, \n]
# 1          03/2017     [\n, 2017, \n]
# 2          02/2016     [\n, 2016, \n]
# 3          08/2016     [\n, 2016, \n]
# 4          02/2016     [\n, 2016, \n]
# ...            ...                ...
# 15755          -/-                NaN
# 15756      01/2019     [\n, 2019, \n]
# 15757      03/2019     [\n, 2019, \n]
# 15758      06/2019     [\n, 2019, \n]
# 15759      01/2019     [\n, 2019, \n]
#
# [15760 rows x 2 columns]

# %%
df.iloc[15755]
# Out:
# url                              https://www.autoscout24.com//offers/renault-es...
# make_model                                                          Renault Espace
# short_description                            Blue dCi 200CV EDC Executive 4Control
# body_type                                                                      Van
# price                                                                        39950
# vat                                                                 VAT deductible
# km                                                                               -
# registration                                                                   -/-
# prev_owner                                                                    None
# kW                                                                             NaN
# hp                                                                          147 kW
# ...

# %%
df[df["First Registration"].isnull()]#this means this car no previous owner
# Out:
#                                                      url      make_model  \
# 120    https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 704    https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 728    https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 735    https://www.autoscout24.com//offers/audi-a1-ad...         Audi A1
# 737    https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15737  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15743  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15748  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15753  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15755  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df[['prev_owner','Previous Owners']]
# Out:
#               prev_owner                                    Previous Owners
# 0      2 previous owners                                              \n2\n
# 1                   None                                                NaN
# 2       1 previous owner                                              \n1\n
# 3       1 previous owner                                              \n1\n
# 4       1 previous owner                                              \n1\n
# ...                  ...                                                ...
# 15755               None                                                NaN
# 15756   1 previous owner  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15757   1 previous owner                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15758               None                                                NaN
# 15759   1 previous owner                                              \n1\n
#
# [15760 rows x 2 columns]

# %%
df[['Next Inspection', 'Inspection new']]
# Out:
#                               Next Inspection  \
# 0       [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15755                                     NaN
# 15756  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15757                                     NaN
# 15758                                     NaN
# 15759                                     NaN
#
#                            Inspection new
# 0                   [\nYes\n, \nEuro 6\n]
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 15755                                 NaN
# 15756                                 NaN
# ...

# %%
df['Next Inspection'][0][0][1:-1]
# Out:
# '06/2021'

# %%
df['Next Inspection']= df['Next Inspection'].str[0].str[1:-1]

# %%
#df1['Next Inspection'].apply(lambda title:title[0][1:-1])

# %%
df["Inspection new"][0][0][1:-1]
# Out:
# 'Yes'

# %%
df["Inspection new"]=df["Inspection new"].str[0].str[1:-1]

# %%
df[['kW', 'hp']]
# Out:
#        kW      hp
# 0     NaN   66 kW
# 1     NaN  141 kW
# 2     NaN   85 kW
# 3     NaN   66 kW
# 4     NaN   85 kW
# ...    ..     ...
# 15755 NaN  147 kW
# 15756 NaN  165 kW
# 15757 NaN  146 kW
# 15758 NaN  147 kW
# 15759 NaN  165 kW
#
# [15760 rows x 2 columns]

# %%
df["hp"][0].split(" ")[0]
# Out:
# '66'

# %%
df["kW"] = df["hp"].apply(lambda hp: hp.split(" ")[0])

# %%
df["kW"]= df["kW"].replace(to_replace='-',value= '0' )

# %%
df["kW"]=pd.to_numeric(df["kW"])

# %%
df["kW"]
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         85
#         ...
# 15755    147
# 15756    165
# 15757    146
# 15758    147
# 15759    165
# Name: kW, Length: 15760, dtype: int64

# %% [markdown]
# **TASK: USE Groupby() method cars:**

# %%
df.groupby("make_model").mean()
# Out:
# C:\Users\ssbil\AppData\Local\Temp\ipykernel_8384\1551941208.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("make_model").mean()
#                        price          kW         kmint
# make_model
# Audi A1         18856.408423   76.586167  21762.501546
# Audi A2         28200.000000   85.000000  26166.000000
# Audi A3         21002.235984   90.184485  38268.501956
# Opel Astra      15836.588165   92.568573  36659.119152
# Opel Corsa      11040.528474   60.187699  24829.872437
# Opel Insignia   21445.123587  113.921637  38255.012476
# Renault Clio    11941.658991   70.261513  28864.332785
# Renault Duster  13230.176471   59.000000     47.529412
# Renault Espace  30081.058943  125.835366  33435.011179

# %%
df.groupby(["make_model","registration"]).mean()
# Out:
# C:\Users\ssbil\AppData\Local\Temp\ipykernel_8384\197702952.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["make_model","registration"]).mean()
#                                     price          kW         kmint
# make_model     registration
# Audi A1        -/-           23217.661538   82.144615    210.566154
#                01/2016       14561.288889   73.622222  59981.955556
#                01/2017       15748.750000   71.214286  47515.571429
#                01/2018       18292.784314   68.882353  17285.058824
#                01/2019       24087.365591   83.591398   2957.677419
# ...                                   ...         ...           ...
# Renault Espace 11/2017       29050.000000   90.647059  29124.941176
# ...

# %%
df.groupby(["make_model","registration"]).mean().index
# Out:
# C:\Users\ssbil\AppData\Local\Temp\ipykernel_8384\686032861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["make_model","registration"]).mean().index
# MultiIndex([(       'Audi A1',     '-/-'),
#             (       'Audi A1', '01/2016'),
#             (       'Audi A1', '01/2017'),
#             (       'Audi A1', '01/2018'),
#             (       'Audi A1', '01/2019'),
#             (       'Audi A1', '02/2016'),
#             (       'Audi A1', '02/2017'),
#             (       'Audi A1', '02/2018'),
#             (       'Audi A1', '02/2019'),
#             (       'Audi A1', '03/2016'),
#             ...
#             ('Renault Espace', '09/2019'),
#             ('Renault Espace', '10/2016'),
#             ('Renault Espace', '10/2017'),
# ...

# %%
df.groupby(["make_model","body_type"]).mean()
# Out:
# C:\Users\ssbil\AppData\Local\Temp\ipykernel_8384\3660915858.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["make_model","body_type"]).mean()
#                                      price          kW         kmint
# make_model     body_type
# Audi A1        Compact        19166.646318   76.922481  20469.669574
#                Coupe          14925.000000   77.500000  38650.000000
#                Other          22026.153846   80.384615   6383.153846
#                Sedans         18631.452930   76.297564  22753.477288
#                Station wagon  17811.380952   75.142857  22421.047619
#                Van            29000.000000  147.000000   3000.000000
# Audi A2        Off-Road       28200.000000   85.000000  26166.000000
# ...

# %%
body_class
# Out:
#                                      price
# make_model     body_type
# Audi A1        Compact        19166.646318
#                Coupe          14925.000000
#                Other          22026.153846
#                Sedans         18631.452930
#                Station wagon  17811.380952
#                Van            29000.000000
# Audi A2        Off-Road       28200.000000
# Audi A3        Compact        19054.994475
#                Convertible    27905.375000
#                Coupe          17745.000000
#                Other          20388.125000
#                Sedans         21169.422179
#                Station wagon  20684.354610
# Opel Astra     Compact        16211.744565
#                Coupe          22240.000000
#                Off-Road       18590.000000
#                Other          13884.984848
#                Sedans         15963.613985
#                Station wagon  15770.613200
# Opel Corsa     Compact        11781.582580
# ...

# %%
body_class.loc[("Renault Clio","Compact")]
# Out:
# price    12626.716667
# Name: (Renault Clio, Compact), dtype: float64

# %%
df["YEAR"] = df["registration"].str[3:]

# %%
df.groupby(["make_model","YEAR"]).mean()
# Out:
# C:\Users\ssbil\AppData\Local\Temp\ipykernel_8384\3899224851.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["make_model","YEAR"]).mean()
#                             price          kW         kmint
# make_model     YEAR
# Audi A1              23217.661538   82.144615    210.566154
#                2016  14484.836276   73.659711  54427.911717
#                2017  16606.114486   75.401869  25883.357477
#                2018  18448.919728   72.902041  13732.021769
#                2019  24241.549266   83.360587   2459.576520
# Audi A2        2018  28200.000000   85.000000  26166.000000
# Audi A3              24140.045752   94.437908      6.029412
#                2016  16472.469790   90.186190  89991.866831
#                2017  19942.016418   88.810448  43802.376119
# ...

# %%
from pandas_profiling import ProfileReport

# %%
#df.profile_report()# Also use profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile = ProfileReport(df, title="Scout Car Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv3.5.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-12-11 15:56:57.207012&quot;&gt;&lt;title&gt;Scout Car Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
